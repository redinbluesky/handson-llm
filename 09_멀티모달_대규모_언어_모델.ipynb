# %% [markdown]
# <a href="https://colab.research.google.com/github/redinbluesky/handson-llm/blob/main/09_멀티모달_대규모_언어_모델.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  목차
# * [Chapter 8 서론](#chapter8)

# %% [markdown]
#         ![밀집 검색](./image/07_dense_search.png)
